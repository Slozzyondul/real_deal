# %%
# %pip install tabula-py pandas
# %pip install jype
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement jype (from versions: none)
# ERROR: No matching distribution found for jype
# Note: you may need to restart the kernel to use updated packages.

# %%
import tabula
import pandas as pd
# Suppress stderr messages

import sys
import warnings
import os

# %%
warnings.filterwarnings("ignore")

# Redirect stderr to null to suppress warnings
sys.stderr = open(os.devnull, 'w')


pdf_file = "/home/solo/Desktop/2022-1.pdf"

# Read the PDF file and extract text data into a DataFrame
df = tabula.read_pdf(pdf_file, pages="all", output_format="dataframe")


# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(df)

# Reset stderr to its default value
sys.stderr = sys.__stderr__

warnings.resetwarnings()

# %%
combined_df
# Out:
#                                              Tran Date  \
# 0                                                  NaN
# 1                                           03-01-2022
# 2                                                  NaN
# 3                                           03-01-2022
# 4                                                  NaN
# ..                                                 ...
# 145  Tran DateValue DateTran ParticularsInstrumentD...
# 146  18-11-2022\r18-11-2022\r18-11-2022\r18-11-2022...
# 147  Tran DateValue DateTran ParticularsInstrumentD...
# 148  22-11-2022\r22-11-2022\r22-11-2022\r22-11-2022...
# 149                                        Grand Total
#
#                                             Value Date  \
# 0                                                  NaN
# 1                                           01-01-2022
# 2                                                  NaN
# 3                                           01-01-2022
# ...
